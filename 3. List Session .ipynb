# %%
bios = ["Iqra", 22, "DS", "iqrayanwar@gmail.com", ["Anwar", 50, "Chef", "anwar@gmail.com",["umer", 7, "student", "umer@gmail.com"]], 77]

# %%
bios
# Out:
# ['Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ['Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ['umer', 7, 'student', 'umer@gmail.com']],
#  77]

# %%
len(bios)
# Out:
# 6

# %%
bios[4][3]
# Out:
# 'anwar@gmail.com'

# %%
bios[4][3]
# Out:
# 'anwar@gmail.com'

# %%
bios[4]
# Out:
# ['Anwar',
#  50,
#  'Chef',
#  'anwar@gmail.com',
#  ['umer', 7, 'student', 'umer@gmail.com']]

# %%
bios[4][:3]
# Out:
# ['Anwar', 50, 'Chef']

# %% [markdown]
# # String Methods

# %%
# anyrhing in double quates and single quates is string

# we also have multi line strings and for that we need tripple quates (""" """ / ''' ''')

# %%
''
# Out:
# ''

# %%
""
# Out:
# ''

# %%
""" """
# Out:
# ' '

# %%
'We have completed 3 sessions!!'
# Out:
# 'We have completed 3 sessions!!'

# %%
'We have completed 3 
sessions!!'
# Out:
#   Cell In[32], line 1
#     'We have completed 3
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
""" we have 
completed
3 sessions
so far """
# Out:
# ' we have \ncompleted\n3 sessions\nso far '

# %%
''' we have completed
3 sessions 
so far by this week'''
## backslash means new lines and if you want to see it organized way write it in print
# Out:
# ' we have completed\n3 sessions \nso far by this week'

# %%
print(''' we have completed
3 sessions 
so far by this week''')
# Out:
#  we have completed
# 3 sessions
# so far by this week

# %% [markdown]
# ##  doc string
# function doc string also requires tripple quates bcs we write multi lines to define the code/ function.

# %% [markdown]
# ## To know string methods
#
# dir(str)

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# # 1. strip() to remove spaces using string method

# %%
# upper, strip, rsplit, lower, isupper, istitle, isspace, startswith, endswith 
"   hello world               "
# Out:
# '   hello world               '

# %%
# we need ti remove spaces

"   hello world               ".strip()
# Out:
# 'hello world'

# %%
"   hello world               ".rstrip()
# Out:
# '   hello world'

# %%
"   hello world               ".lstrip()
# Out:
# 'hello world               '

# %% [markdown]
# # 2. to separate or split data / string

# %%
''' we have completed 3 sessionsso far by this week'''.split()
# Out:
# ['we', 'have', 'completed', '3', 'sessionsso', 'far', 'by', 'this', 'week']

# %%
a = ''' we:have:completed 3 sessionsso: far by: this week'''.split(":")
a
# Out:
# [' we', 'have', 'completed 3 sessionsso', ' far by', ' this week']

# %%
a[2:4]
# Out:
# ['completed 3 sessionsso', ' far by']

# %%
a[-1]
# Out:
# ' this week'

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# # 3.

# %%
"hi im iqra"
# Out:
# 'hi im iqra'

# %%
"hi im iqra".upper()
# Out:
# 'HI IM IQRA'

# %%
"hi im iqra".replace("iqra", "umar")
# Out:
# 'hi im umar'

# %%
text = "hi im iqra"
text
# Out:
# 'hi im iqra'

# %%
#slicing
text[2]
# Out:
# ' '

# %%
#slicing
text[6:] = "alii"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 #slicing
# ----> 2 text[6:] = "alii"
#
# TypeError: 'str' object does not support item assignment

# %%
text.replace(shit + tab )

# %% [markdown]
# # TUPLE

# %%
tuple_bio = ("Iqra", 22, "DS", "iqrayanwar@gmail.com", ["Anwar", 50, "Chef", "anwar@gmail.com",["umer", 7, "student", "umer@gmail.com"]], 77)

# %%
tuple_bio
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ['Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ['umer', 7, 'student', 'umer@gmail.com']],
#  77)

# %%
tuple_nested = ("Iqra", 22, "DS", "iqrayanwar@gmail.com", ("Anwar", 50, "Chef", "anwar@gmail.com",("umer", 7, "student", "umer@gmail.com")), 77)

# %%
tuple_nested
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ('Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ('umer', 7, 'student', 'umer@gmail.com')),
#  77)

# %%
tuple_nested
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ('Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ('umer', 7, 'student', 'umer@gmail.com')),
#  77)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tuple_nested[1:4]
# Out:
# (22, 'DS', 'iqrayanwar@gmail.com')

# %%
tuple_nested[2]
# Out:
# 'DS'

# %%
tuple_nested[2] = "DA"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 tuple_nested[2] = "DA"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_nested
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ('Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ('umer', 7, 'student', 'umer@gmail.com')),
#  77)

# %%
type(tuple_nested)
# Out:
# tuple

# %%
tuple_bio
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ['Anwar',
#   50,
#   'Chef',
#   'anwar@gmail.com',
#   ['umer', 7, 'student', 'umer@gmail.com']],
#  77)

# %%
tuple_bio[4][3] = "anwarali@gmail.com"

# %%
tuple_bio
# Out:
# ('Iqra',
#  22,
#  'DS',
#  'iqrayanwar@gmail.com',
#  ['Anwar',
#   50,
#   'Chef',
#   'anwarali@gmail.com',
#   ['umer', 7, 'student', 'umer@gmail.com']],
#  77)

# %%
num1 = (1,4)
num2 = (5,7)

# %%
num1 * 3
# Out:
# (1, 4, 1, 4, 1, 4)

# %%
num1 + num2
# Out:
# (1, 4, 5, 7)

# %%
num2 - num1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 num2 - num1
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %% [markdown]
# # unpacking

# %%
# unpacking can be in list and tuple both

bios = ["iqra", 22, "iqraanwar@gmail.com",["umer", 6, "stu", "umar@gmail.com"]]

# %%
name, age, email, *others_info = bios

# %%
name, age, email, *others_info = bios

# %%
name
# Out:
# 'iqra'

# %%
others_info
# Out:
# [['umer', 6, 'stu', 'umar@gmail.com']]
